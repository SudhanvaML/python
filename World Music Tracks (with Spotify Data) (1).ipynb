# %%
#Importing libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#Creating a DataFrame

df=pd.read_csv(r'D:\NIE\2nd Sem\Python\Data Analysis\WorldHits (Spotify Data).csv')
data=pd.DataFrame(df)
print(data)
# Out:
#                                Track                  Artist  \
# 0                            Release  Afro Celt Sound System
# 1    Saor / Free / News from Nowhere  Afro Celt Sound System
# 2                When You're Falling  Afro Celt Sound System
# 3                     Whirl-Y-Reel 1  Afro Celt Sound System
# 4                Electric Rendezvous             Al Di Meola
# ..                               ...                     ...
# 321                           Birima          Youssou N'Dour
# 322                       Mame Bamba          Youssou N'Dour
# 323                         Salimata          Youssou N'Dour
# 324                              Set          Youssou N'Dour
# 325                        Wiri-Wiri          Youssou N'Dour
#
#                                             Album  Year  Duration  \
# 0             Volume 2: Release (Real World Gold)  2005    456160
# 1           Vol. 1: Sound Magic (Real World Gold)  1999    501093
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326 entries, 0 to 325
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Track         326 non-null    object
#  1   Artist        326 non-null    object
#  2   Album         326 non-null    object
#  3   Year          326 non-null    int64
#  4   Duration      326 non-null    int64
#  5   Danceability  326 non-null    float64
#  6   Energy        326 non-null    float64
#  7   Key           282 non-null    float64
#  8   Loudness      326 non-null    float64
#  9   Tempo         326 non-null    float64
#  10  Popularity    326 non-null    int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 28.1+ KB

# %%
data.head()
# Out:
#                              Track                  Artist  \
# 0                          Release  Afro Celt Sound System
# 1  Saor / Free / News from Nowhere  Afro Celt Sound System
# 2              When You're Falling  Afro Celt Sound System
# 3                   Whirl-Y-Reel 1  Afro Celt Sound System
# 4              Electric Rendezvous             Al Di Meola
#
#                                           Album  Year  Duration  Danceability  \
# 0           Volume 2: Release (Real World Gold)  2005    456160         0.633
# 1         Vol. 1: Sound Magic (Real World Gold)  1999    501093         0.511
# 2  Volume 3 : Further In Time (Real World Gold)  2003    314160         0.638
# 3         Vol. 1: Sound Magic (Real World Gold)  1999    441200         0.645
# 4                           Electric Rendezvous  1982    467266         0.337
#
#    Energy   Key  Loudness    Tempo  Popularity
# 0   0.828   5.0    -7.266  100.089          31
# ...

# %%
data.tail()
# Out:
#           Track          Artist               Album  Year  Duration  \
# 321      Birima  Youssou N'Dour      Joko: The Link  1995    228373
# 322  Mame Bamba  Youssou N'Dour  The Guide (Wommat)  1990    296893
# 323    Salimata  Youssou N'Dour             History  1988    254133
# 324         Set  Youssou N'Dour                 Set  2004    226826
# 325   Wiri-Wiri  Youssou N'Dour      Joko: The Link  2007    247466
#
#      Danceability  Energy   Key  Loudness    Tempo  Popularity
# 321         0.692   0.737  10.0    -7.042  105.754          18
# 322         0.662   0.577  10.0   -14.089  140.991          16
# 323         0.634   0.818   NaN    -6.085  119.598          20
# 324         0.733   0.730   NaN   -11.056  146.213          25
# 325         0.654   0.516   5.0   -10.325   83.013           5

# %%
data.isnull().sum()
# Out:
# Track            0
# Artist           0
# Album            0
# Year             0
# Duration         0
# Danceability     0
# Energy           0
# Key             44
# Loudness         0
# Tempo            0
# Popularity       0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Track           326
# Artist          326
# Album           326
# Year            326
# Duration        326
# Danceability    326
# Energy          326
# Key             282
# Loudness        326
# Tempo           326
# Popularity      326
# dtype: int64

# %%
data.shape
# Out:
# (326, 11)

# %%
data.describe()
# Out:
#               Year      Duration  Danceability      Energy         Key  \
# count   326.000000  3.260000e+02    326.000000  326.000000  282.000000
# mean   1992.407975  3.337062e+05      0.522381    0.502092    6.251773
# std      12.680298  2.680486e+05      0.170469    0.259283    3.128974
# min    1958.000000  4.188000e+04      0.078800    0.005620    1.000000
# 25%    1985.000000  2.124700e+05      0.404250    0.292250    4.000000
# 50%    1995.000000  2.648330e+05      0.542000    0.489500    7.000000
# 75%    2002.000000  3.498832e+05      0.657750    0.729000    9.000000
# max    2019.000000  3.060650e+06      0.946000    0.985000   11.000000
#
#          Loudness       Tempo  Popularity
# count  326.000000  326.000000  326.000000
# mean   -11.799755  115.968460   28.346626
# std      5.159427   28.174109   15.960512
# min    -36.178000   44.757000    0.000000
# 25%    -14.645000   94.757500   17.000000
# 50%    -11.055500  112.277000   28.000000
# ...

# %%
data.columns
# Out:
# Index(['Track', 'Artist', 'Album', 'Year', 'Duration', 'Danceability',
#        'Energy', 'Key', 'Loudness', 'Tempo', 'Popularity'],
#       dtype='object')

# %%
#Unique Artists count
len(data['Artist'].value_counts())
# Out:
# 66

# %%
#Accessing Multiple Columns
data[['Track','Artist']]
# Out:
#                                Track                  Artist
# 0                            Release  Afro Celt Sound System
# 1    Saor / Free / News from Nowhere  Afro Celt Sound System
# 2                When You're Falling  Afro Celt Sound System
# 3                     Whirl-Y-Reel 1  Afro Celt Sound System
# 4                Electric Rendezvous             Al Di Meola
# ..                               ...                     ...
# 321                           Birima          Youssou N'Dour
# 322                       Mame Bamba          Youssou N'Dour
# 323                         Salimata          Youssou N'Dour
# 324                              Set          Youssou N'Dour
# 325                        Wiri-Wiri          Youssou N'Dour
#
# [326 rows x 2 columns]

# %%
#Single condition
df=data[data['Year']>2005]
df.head()
# Out:
#                      Track                Artist             Album  Year  \
# 11  Banga (with Ry Cooder)       Ali Farka Touré  Talking Timbuktu  2013
# 12  Bonde (with Ry Cooder)       Ali Farka Touré  Talking Timbuktu  2013
# 17                  Savane       Ali Farka Touré            Savane  2006
# 54           A Szerelemről  Both Miklós Folkside     Csillagfészek  2010
# 55           Csillagfészek  Both Miklós Folkside     Csillagfészek  2010
#
#     Duration  Danceability  Energy   Key  Loudness    Tempo  Popularity
# 11    152826         0.511   0.306  11.0   -22.718   77.991          29
# 12    328826         0.514   0.532   2.0   -17.026  113.821          45
# 17    463266         0.776   0.279   4.0   -10.450  135.866          40
# 54    395933         0.351   0.256   7.0   -11.140   59.520           0
# 55    342293         0.452   0.720   7.0    -6.923  150.125           0

# %%
#Multiple condition
df=data[(data['Year']>2005) & (data['Popularity']>40)]
df.loc[0:,('Year','Popularity')]
# Out:
#      Year  Popularity
# 12   2013          45
# 66   2007          61
# 134  2015          57
# 162  2007          41
# 227  2012          50
# 267  2009          48
# 315  2006          45
# 317  2009          52
# 318  2008          52

# %%
#Sorting the data
df=data.sort_values(by='Year', ascending=False)
df
# Out:
#                                            Track              Artist  \
# 64   Baila Mami (feat. Nailah Blackman & Lao Ra)        Calypso Rose
# 271        No me Vayas a Engañar - 2019 Remaster     Omara Portuondo
# 134                               Echoes in Rain                Enya
# 11                        Banga (with Ry Cooder)     Ali Farka Touré
# 312                                      Courage   Vieux Farka Touré
# ..                                           ...                 ...
# 89                    She Moved Through The Fair         Davy Graham
# 34                      Akiwowo (Ah-Key-Woh-Woh)  Babatunde Olatunji
# 150                             Comin' Home Baby         Herbie Mann
# 35                 Jin-Go-Lo-Ba (Jin-Go-Low-Bah)  Babatunde Olatunji
# 311                                   Tom Dooley   The Kingston Trio
#
#                                                  Album  Year  Duration  \
# ...

# %%
#Creating new column
data['Danceability in Percentage']=data['Danceability']*100
data
# Out:
#                                Track                  Artist  \
# 0                            Release  Afro Celt Sound System
# 1    Saor / Free / News from Nowhere  Afro Celt Sound System
# 2                When You're Falling  Afro Celt Sound System
# 3                     Whirl-Y-Reel 1  Afro Celt Sound System
# 4                Electric Rendezvous             Al Di Meola
# ..                               ...                     ...
# 321                           Birima          Youssou N'Dour
# 322                       Mame Bamba          Youssou N'Dour
# 323                         Salimata          Youssou N'Dour
# 324                              Set          Youssou N'Dour
# 325                        Wiri-Wiri          Youssou N'Dour
#
#                                             Album  Year  Duration  \
# 0             Volume 2: Release (Real World Gold)  2005    456160
# 1           Vol. 1: Sound Magic (Real World Gold)  1999    501093
# ...

# %%
#Dropping the empty cell
data['Key'].dropna()
data
# Out:
#                                Track                  Artist  \
# 0                            Release  Afro Celt Sound System
# 1    Saor / Free / News from Nowhere  Afro Celt Sound System
# 2                When You're Falling  Afro Celt Sound System
# 3                     Whirl-Y-Reel 1  Afro Celt Sound System
# 4                Electric Rendezvous             Al Di Meola
# ..                               ...                     ...
# 321                           Birima          Youssou N'Dour
# 322                       Mame Bamba          Youssou N'Dour
# 323                         Salimata          Youssou N'Dour
# 324                              Set          Youssou N'Dour
# 325                        Wiri-Wiri          Youssou N'Dour
#
#                                             Album  Year  Duration  \
# 0             Volume 2: Release (Real World Gold)  2005    456160
# 1           Vol. 1: Sound Magic (Real World Gold)  1999    501093
# ...

# %%
#Filling the empty cell with NaN
data['Key'].fillna('NaN')
# Out:
# 0       5.0
# 1       7.0
# 2      11.0
# 3       2.0
# 4       9.0
#        ...
# 321    10.0
# 322    10.0
# 323     NaN
# 324     NaN
# 325     5.0
# Name: Key, Length: 326, dtype: object

# %%
#Counting empty row
data['Key'].isnull().sum()
# Out:
# 44

# %%
#Unique Artists
data['Artist'].unique()
# Out:
# array(['Afro Celt Sound System', 'Al Di Meola', 'Ali Farka Touré',
#        'Ali Mohammed Birra', 'Angelique Kidjo', 'Babatunde Olatunji',
#        'Bill Frisell', 'Boban Markovic Orkestar', 'Bobby McFerrin',
#        'Both Miklós Folkside', 'Bulgarian State Television Female Choir',
#        'Burlap To Cashmere', 'Calypso Rose', 'Capercaillie', 'Celso Piña',
#        'Cesária Evora', 'Chico César', 'Christina Shusho',
#        'David Lindley', 'Davy Graham', 'Dead Can Dance', 'Deepak Dev',
#        'Demis Roussos', 'Dhafer Youssef', 'Diane Arkenstone',
#        'Dr Nele Karajlic', 'Dulce Pontes', 'Eliades Ochoa', 'Enya',
#        'Fela Kuti', 'Herbie Mann', 'Ibrahim Ferrer', 'Idan Raichel',
#        'Ilaiyaraaja', 'Inti-Illimani', 'Ismaël Lô',
#        "Jah Wobble's Invaders Of The Heart", 'Joe Zawinul', 'John Zorn',
#        'Jon Hassell', 'Jon Stefans', 'Jónsi', 'Karl-Martin Almqvist',
#        'Kirsty MacColl', 'Ladysmith Black Mambazo',
# ...

# %%
#Unique Artists Count
data['Artist'].nunique()
# Out:
# 66

# %%
#Renaming Column
data.rename(columns={'Artist':'Artist Name'}, inplace=True)
data
# Out:
#                                Track             Artist Name  \
# 0                            Release  Afro Celt Sound System
# 1    Saor / Free / News from Nowhere  Afro Celt Sound System
# 2                When You're Falling  Afro Celt Sound System
# 3                     Whirl-Y-Reel 1  Afro Celt Sound System
# 4                Electric Rendezvous             Al Di Meola
# ..                               ...                     ...
# 321                           Birima          Youssou N'Dour
# 322                       Mame Bamba          Youssou N'Dour
# 323                         Salimata          Youssou N'Dour
# 324                              Set          Youssou N'Dour
# 325                        Wiri-Wiri          Youssou N'Dour
#
#                                             Album  Year  Duration  \
# 0             Volume 2: Release (Real World Gold)  2005    456160
# 1           Vol. 1: Sound Magic (Real World Gold)  1999    501093
# ...

# %%
#Dropping Key column
data.drop(['Key'],axis=1)
# Out:
#                                Track             Artist Name  \
# 0                            Release  Afro Celt Sound System
# 1    Saor / Free / News from Nowhere  Afro Celt Sound System
# 2                When You're Falling  Afro Celt Sound System
# 3                     Whirl-Y-Reel 1  Afro Celt Sound System
# 4                Electric Rendezvous             Al Di Meola
# ..                               ...                     ...
# 321                           Birima          Youssou N'Dour
# 322                       Mame Bamba          Youssou N'Dour
# 323                         Salimata          Youssou N'Dour
# 324                              Set          Youssou N'Dour
# 325                        Wiri-Wiri          Youssou N'Dour
#
#                                             Album  Year  Duration  \
# 0             Volume 2: Release (Real World Gold)  2005    456160
# 1           Vol. 1: Sound Magic (Real World Gold)  1999    501093
# ...

# %%
#Popularity over the time
sns.relplot(x="Year",y="Popularity",kind='line',data=data)

# %%
#Danceability Count
plt.figure(figsize=(10,6))
sns.lineplot(x='Year',y='Danceability',data=data,color='red')
plt.title('Trends in Danceability over time')
plt.show()

# %%
# Sorting the data by Popularity for the top 10 tracks
top_10_data = data.nlargest(10, 'Popularity')

sns.barplot(x='Popularity', y='Track', data=top_10_data)

for index, value in enumerate(top_10_data['Popularity']):
    plt.text(value, index, str(value),color='green',va='center',fontweight='bold')
plt.show()

# %%
#Number of listeners
plt.figure(figsize=(10,6))
plt.hist([data['Tempo'],data['Popularity']])
plt.xlabel('Count')
plt.ylabel('No.of listeners')
plt.legend(['Tempo'])
plt.show()

# %%
#Maximum number in each key
y=['Popularity','Tempo']
width=data['Popularity'].max(),data['Tempo'].max()
plt.figure(figsize=(10,3))
plt.barh(y=y,width=width)
plt.title('Maximum number in each key')
for i,v in enumerate(width):
    plt.text(v,i," "+str(round(v)),color='green',va='center',fontweight='bold')
plt.show()

# %%
#Number of songs released per year
top = data['Year'].value_counts().nlargest(10).index
top_data = data[data['Year'].isin(top)]

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Year', data=top_data)
plt.title("Number of songs released per year")

for i,v in enumerate(ax.patches):
    height = v.get_height()
    ax.text(v.get_x() + v.get_width() / 2., height + 0.5, 
            f'{int(height)}', ha="center", va='center', 
            fontweight='bold', color='green')

plt.show()

# %%
#Popularity is equal to 45 then replace it with NaN
df.loc[df['Popularity'] == 45, 'Popularity'] = np.NaN
df
# Out:
#                                                  Track             Artist  \
# 12                              Bonde (with Ry Cooder)    Ali Farka Touré
# 66                                       Calypso Queen       Calypso Rose
# 134                                     Echoes in Rain               Enya
# 162   Ve'Eem Tavo'ee Elay (And If You Will Come To Me)       Idan Raichel
# 227  Bongo Bong - Je ne t'aime plus (Francis Mercie...          Manu Chao
# 267                                 ¿Dónde Estabas Tú?    Omara Portuondo
# 315                                          Mahine Me  Vieux Farka Touré
# 317                                            Savanne  Vieux Farka Touré
# 318                                        Tongo Barra  Vieux Farka Touré
#
#                                                  Album  Year  Duration  \
# 12                                    Talking Timbuktu  2013    328826
# 66                                       Far from Home  2007    197813
# ...
